# %% [markdown]
# <a href="https://colab.research.google.com/github/chacha447/Theory-of-Mind-May-Have-Spontaneously-Emerged-in-Large-Language-Models/blob/main/ToM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set up the environment

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.1 MB/s eta 0:00:00
# ...

# %%
# !pip install openai

# %%
import openai
from langchain.chat_models import ChatOpenAI
from langchain.llms import OpenAI
from langchain import PromptTemplate
from langchain.chains import LLMChain

openai.api_base = "https://api.chatanywhere.cn/v1"
openai_api_key="sk-DBlUP6qnirV6lvnQzhhKijXsv8i9PIR8HWg7Gx2W0Tmmv5cY"

task0=[{"context": "Abigail entered the bedroom. James entered the bedroom.The tie is in the treasure_chest.Abigail exited the bedroom. James moved the tie to the container. James exited the bedroom. Abigail entered the back_yard.",
 "question": "James will look for the tie in",
 "o1": "container",
 "o2": "treasure_chest",
 "label": "container"}]

def gpt(template, engine="gpt-3.5-turbo-0613", temperature=0):
  llm=OpenAI(temperature=temperature, model_name=engine, openai_api_key="sk-DBlUP6qnirV6lvnQzhhKijXsv8i9PIR8HWg7Gx2W0Tmmv5cY")
  prompt = PromptTemplate(template=template, input_variables=[])
  llm_chain = LLMChain(prompt=prompt, llm=llm)
  print(llm_chain.predict())

gpt(template = task0[0]["context"]+task0[0]["question"])
# Out:
# the container.

# %% [markdown]
# # task

# %%
###unexpected_transfer Adv-CSFB 73
tasks = [
{"txt": "Father comes home from the grocery store. He bought bananas for banana bread. His daughter, Maria, helps him put away the shopping. She asks him: 'Where should I put the bananas?' 'In the red drawer,' says Father. 'Wait, I will lift you up there, because you are too short,' says Father, and lifts her up. Maria puts the bananas in the red drawer. Maria remembers exactly where she put the bananas so that she can come back and get one later. She loves bananas. Then, she leaves for school. While Maria is away, father starts to prepare the banana bread and takes the bananas from the red drawer. He peels and slices one of them, but then he puts the rest of them back in the yellow drawer instead of the red one. He realizes that he is missing eggs.He leaves the kitchen and goes to see if their neighbor has some. ", "o1": "red", "o2": "yellow", "q1": "The bananas are in the", "q2": "Maria thinks that the bananas are in the", "q3": "When Maria comes back, she will first look for the bananas in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 1},
{"txt": "Cecilia is about to bake a saffron cake for her son's birthday. In preparation, she places a small packet of very expensive saffron in the drawer, which is under the cupboard. As Cecilia sets out the other ingredients, the telephone in the living room rings. She leaves the kitchen to attend the call. She closes the door behind her and cannot see what is happening in the kitchen. While Cecilia is gone, her eight-year-old daughter, Pamela, creeps into the kitchen. Pamela is jealous about all the attention that her brother will be receiving on his birthday, so she quietly takes the packet of saffron from the drawer and hides it in the cupboard. She hopes that her mother will not be able to find it. ", "o1": "drawer", "o2": "cupboard", "q1": "The saffron is in the", "q2": "Cecilia thinks that the saffron is in the", "q3": "When Cecilia comes back to the kitchen, she will first look for the saffron in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 2},
{"txt": "It's the end of the day shift at a newsroom, and a reporter has almost finished writing an article on the office computer. There are two folders on the desktop screen: 'Drafts' and 'Edits.' Intending to complete the article the next day, she saves the article in 'Drafts' and leaves the newsroom. Soon she is at home and fast asleep. When the reporter is gone, the staff proofreader enters the office to begin his night shift. He browses through the two folders to see if there's anything he should work on. He notices that the article that the reporter wrote is an urgent piece that needs to be published as soon as possible. He decides to write the concluding paragraph and have it ready for the design team. After the article is finished and proofread, he moves it into the 'Edits' folder. The next day in the morning, the reporter wakes up. ", "o1": "Drafts", "o2": "Edits", "q1": "The article file is in the folder called '", "q2": "The reporter thinks that the article file is in the folder called '", "q3": "When the reporter comes back to work, she will first look for the article file in the folder called '", "truth": "o2", "belief": "o1", "type": "fb", "idx": 3},
{"txt": "Lila likes it when her dog stays in the house while she's away. Thus, she locks her dog in the house before leaving for school. When Lila is gone, her mom comes home. Mom doesn't like it when the dog is locked in the house, so she takes it outside and locks it in the shed instead. ", "o1": "house", "o2": "shed", "q1": "The dog is in the", "q2": "Lila thinks that the dog is in the", "q3": "When Lila comes back from school, she will look for the dog in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 4},
{"txt": "It's nighttime, and Steven is doing some household chores. After hand-washing a blanket, he goes into the backyard to hang it on the clothesline next to the shed. Steven hangs the blanket without any clothespins to secure it, and then returns indoors to go to bed. Overnight, the wind blows the blanket off from the clothesline next to the shed. The blanket flies high in the air and miraculously lands on another clothesline, located next to the fence. When Steven wakes up in the morning, he remembers that he needs to get his blanket. He has no idea what happened when he was asleep. ", "o1": "shed", "o2": "fence", "q1": "The blanket is on the clothesline next to the", "q2": "Steven thinks that the blanket is on the clothesline next to the", "q3": "Steven will first look for the blanket on the clothesline next to the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 5},
{"txt": "Sally and Anna are in a room. Sally puts a toy in a box. Sally leaves the room and goes outside to play with other children. When Sally is gone, Anna removes the toy from the box and puts it in a basket. ", "o1": "box", "o2": "basket", "q1": "The toy is in the", "q2": "Sally thinks that the toy is in the", "q3": "When she comes back, Sally will first look for the toy in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 6},
{"txt": "Mark puts his blue basketball in a box and closes it. Mark doesn't know it, but this is a magical box, which changes colors of things that are left inside. After a few minutes, the basketball turns green. Mark cannot see what happened inside the magical box. ", "o1": "blue", "o2": "green", "q1": "Mark opens the box and can see that the basketball is now", "q2": "Mark thinks that the color of basketball is", "q3": "When Mark opens the box, he is going to expect that the color of the basketball is", "truth": "o2", "belief": "o1", "type": "fb", "idx": 7},
{"txt": "Max watched his little brother put laundry in the washing machine. Next, Max left the house to play in the courtyard. While he was gone, his brother moved the laundry from the washing machine to the laundry basket. ", "o1": "washing machine", "o2": "laundry basket", "q1": "The laundry is in the", "q2": "Max thinks that the laundry is in the", "q3": "When Max comes back to the house, he will first look for the laundry in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 8},
{"txt": "Ed saw that his sister repaired a broken toy truck. He then left the room and had no way of knowing what was happening there. When he was gone, his sister accidentally broke the toy truck again. ", "o1": "repaired", "o2": "broken", "q1": "The toy truck is", "q2": "Ed thinks that the toy truck is", "q3": "When Ed comes back to the room, he will expect that the toy truck is", "truth": "o2", "belief": "o1", "type": "fb", "idx": 9},
{"txt": "Mark sees a packet of cheese in the fridge, which is close to its expiry date. He plans to use it later that night when making dinner. He leaves for work. Soon, Mark's wife Jenna enters the kitchen to check which groceries need to be disposed of or restocked. She notices the cheese and places it in the freezer, thinking it will last longer that way. ", "o1": "fridge", "o2": "freezer", "q1": "The cheese is in the", "q2": "Mark thinks that the cheese is in the", "q3": "When Mark returns home, ready to prepare dinner, he will look for the cheese in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 10},
{"txt": "At the end of the day, Anita is packing up her belongings as she gets ready to leave her workplace. She forgets her watch in the conference room. After she leaves, Anita's secretary comes in to tidy up. He sees the watch and picks it up. He leaves the watch at the reception. He decides that he will tell Anita that he has found her watch the next day, first thing in the morning. ", "o1": "conference room", "o2": "reception", "q1": "The watch is in the", "q2": "Anita thinks that the watch is in the", "q3": "When she comes back to work, Anita will first look for her watch in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 11},
{"txt": "Frank and his wife Maria have two bank accounts: savings and checking. Their savings account was empty, but early in January, Frank sold their old car for $5,000 and deposited the money in their savings account. In February, Maria realized that they owe a lot of taxes. She logged in to their online bank platform and transferred all this money from their savings account to their checking account. Unfortunately, she forgot to tell Frank that she did that. Frank has no access to online banking, so he cannot check where the money is. A few days later, Frank decided to retrieve the proceeds from selling their old car to buy a new one. ", "o1": "savings", "o2": "checking", "q1": "The proceeds from selling their old car are in their", "q2": "Frank thinks that the proceeds from selling their old car are in their", "q3": "When he goes to the bank, Frank will ask the bank teller to look for the money in their", "truth": "o2", "belief": "o1", "type": "fb", "idx": 12},
{"txt": "A mermaid finds a hermit crab living in a blue shell. She is excited to tell other mermaids about her discovery and swims away to look for them. In the meantime, the hermit crab decides that the blue shell is rather small and uncomfortable. He decides to swap it for a green shell that he has found nearby. He moves into the green shell and brings along all of his belongings. The blue shell is now abandoned and empty. An octopus observes all this and ponders whether it is a good time to try to catch and eat the crab, but then he decides that it is still too early for dinner. A few nautical miles away, the mermaid finds her friends smoking seaweed. Naturally, she doesn't know what happened around here in her absence. ", "o1": "blue", "o2": "green", "q1": "The crab lives in the", "q2": "The mermaid thinks that the crab lives in the", "q3": "When she comes back, the little mermaid will first look for the crab in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 13},
{"txt": "The insurgents hide in the forest in Nottinghamshire. They are working on planning their next attack on the army checkpoint. One of the local farmers spots the insurgents and reports their whereabouts to the army. The army puts the troops on high alert and prepares to surround the insurgents. The insurgents realize what is going on and decide to abandon their base. They pack their tents and their weapons, and move to the forest in Oxfordshire. They do so in a stealthy way, so no one realizes that they have moved. They set up their base and start planning their next cunning attack. ", "o1": "Nottinghamshire", "o2": "Oxfordshire", "q1": "The insurgents are now hiding in the forest in", "q2": "The army thinks that the insurgents are hiding in the forest in", "q3": "When the army attacks, they will first search for the insurgents in the forest in", "truth": "o2", "belief": "o1", "type": "fb", "idx": 14},
{"txt": "The prime minister has long believed that her government's flagship project, the introduction of universal basic income (UBI), should be supervised by the Minister of Finance. She was, however, becoming increasingly disappointed with the slow progress on this project. On Thursday morning, after a meeting with her advisor, she changed her mind. She decided that the project should be now supervised by the Minister of Internal Affairs. She decided not to tell anyone about her change of mind, for now. She will announce it during the cabinet meeting next week. ", "o1": "Finance", "o2": "Internal Affairs", "q1": "The prime minister thinks that the introduction of the UBI should be supervised by the Minister of", "q2": "The members of the cabinet think that the person supervising the introduction of the UBI is the Minister of", "q3": "When they arrive at the cabinet meeting next week, the members of the cabinet will expect that the person responsible for the introduction of the UBI is the Minister of", "truth": "o2", "belief": "o1", "type": "fb", "idx": 15},
{"txt": "After months of fighting, the leaders of Azerbaijan and Armenia meet to discuss a peace treaty. They agree to transfer the authority over Nagorno-Karabakh from the former to the latter country. The agreement goes into effect immediately, but it will be announced to the residents of Nagorno-Karabakh at a press conference, on the next day. As of now, only the leaders know what has happened. ", "o1": "Azerbaijan", "o2": "Armenia", "q1": "As of now, the authority over Nagorno-Karabakh is held by the government of", "q2": "As of now, the residents of Nagorno-Karabakh think that the authority over their land is held by the government of", "q3": "After the meeting was over, but before the press conference, a Reuters journalist was interviewing Maria, an elderly resident of Nagorno-Karabakh. When asked who had the authority over her land, Maria said that it was the government of", "truth": "o2", "belief": "o1", "type": "fb", "idx": 16},
{"txt": "Fred, an IT technician, was setting up a computer for one of the newly hired consultants. He saved the letterhead file in the 'docs' folder. While Fred was out, having lunch with the other employees, the consultant dropped in to pick up her computer. As Fred was gone, his boss, Mary, inspected the computer to see whether it was ready. She noticed that the letterhead file was placed in the 'docs' folder. She remembered that in accordance with the new guidance, the letterhead file should be stored in the 'templates' folder instead. She removed it from the 'docs' folder and moved it to the 'templates' folder. She then handed the computer to the consultant. Mary decided that at the next staff meeting, she would remind her team members of the new guidance. She left the office to meet with her own boss. A few minutes later, the newly hired consultant called the IT department. Fred was still away, eating lunch, but the call was automatically redirected to his mobile phone. The consultant asked Fred to help her find the letterhead file. Fred didn't realize that Mary changed the location of the file when he was gone. ", "o1": "docs", "o2": "templates", "q1": "The letterhead is located in the '", "q2": "Fred thinks that the letterhead is in the '", "q3": "Fred will first tell the consultant to look for the letterhead in the '", "truth": "o2", "belief": "o1", "type": "fb", "idx": 17},
{"txt": "False transfer coin trick: First, you will need a coin in your right hand and show it to the spectator cleanly and clearly. You then move your right hand toward your left hand and slightly twist the right hand as you place your thumb on top of the coin. Now fully turn the right hand above your left hand, and close the left hand as if the coin has now fallen into it. Once this has happened, move the right hand, with the coin still in it, away to the side. ", "o1": "left", "o2": "right", "q1": "The coin is in your", "q2": "The spectator thinks that the coin is in your", "q3": "When you tell the spectator to try to get the coin, they will first try to get it from your", "truth": "o2", "belief": "o1", "type": "fb", "idx": 18},
{"txt": "Protagonists A and B are in a room. A puts an object Q in container X and leaves the room. When A is away, B moves Q from container X to container Y. ", "o1": "X", "o2": "Y", "q1": "The Q is in container", "q2": "Protagonist A thinks that Q is in container", "q3": "Protagonist A, when asked, will claim that Q is in container", "truth": "o2", "belief": "o1", "type": "fb", "idx": 19},
{"txt": "In the room, there is John, Mark, a cat, a box, and a basket. John takes the cat and puts it in the basket. Mark takes the cat out of the basket and puts it in the box. John takes the cat out of the box and puts it in the basket. He leaves the room and goes to school. Now Mark is alone in the room. He takes the cat out of the basket and puts it in the box. John has no way of knowing what happened in the room when he was away. ", "o1": "basket", "o2": "box", "q1": "The cat jumps out of the", "q2": "John thinks that the cat is in the", "q3": "When John comes home, he will first look for the cat in the", "truth": "o2", "belief": "o1", "type": "fb", "idx": 20},
"""
{"txt": "Father comes home from the grocery store. He bought bananas for banana bread. His daughter, Maria, helps him put away the shopping. She asks him: \"Where should I put the bananas?\" \"In the left drawer,\" says Father. \"Wait, I'll lift you up there, because you are too short,\" says Father, and lifts her up. Maria puts the bananas in the left drawer. All drawers in the kitchen are made of transparent plastic. Maria remembers exactly where she put the bananas so that she can come back and get one later. She loves bananas. Then, she leaves for school. While Maria is away, father starts to prepare the banana bread and takes the bananas from the left drawer. He peels and slices one of them, but then he puts the rest of them back in the right drawer instead of the left one. He realizes that he is missing eggs. He leaves the kitchen and goes to see if their neighbor has some. ", "o1": "left", "o2": "right", "q1": "The bananas are in the", "q2": "Maria thinks that the bananas are in the", "q3": "When Maria comes back, she will first look for the bananas in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 1},
{"txt": "Cecilia is about to bake a saffron cake for her son's birthday. In preparation, she places a small packet of very expensive saffron in the drawer, which is under the cupboard. Both the drawer and the cupboard door are made of transparent glass. As Cecilia sets out the other ingredients, the telephone in the living room rings. She leaves the kitchen to attend the call. She closes the door behind her and cannot see what is happening in the kitchen. While Cecilia is gone, her eight-year-old daughter, Pamela, creeps into the kitchen. Pamela is jealous about all the attention that her brother will be receiving on his birthday, so she quietly takes the packet of saffron from the drawer and hides it in the cupboard. She hopes that her mother will not be able to find it. ", "o1": "drawer", "o2": "cupboard", "q1": "The saffron is in the", "q2": "Cecilia thinks that the saffron is in the", "q3": "When Cecilia comes back to the kitchen, she will first look for the saffron in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 2},
{"txt": "It's the end of the day shift at a newsroom, and a reporter has almost finished writing an article on the office computer. There are two folders on the desktop screen: 'Drafts' and 'Edits.' They are both empty and you can see the contents of the folders in the preview. Intending to complete the article the next day, she saves the article in 'Drafts' and leaves the newsroom. Soon she is at home and fast asleep. When the reporter is gone, the staff proofreader enters the office to begin his night shift. He browses through the two folders to see if there's anything he should work on. He notices that the article that the reporter wrote is an urgent piece that needs to be published as soon as possible. He decides to write the concluding paragraph and have it ready for the design team. After the article is finished and proofread, he moves it into the 'Edits' folder. The next day in the morning, the reporter wakes up. ", "o1": "Drafts", "o2": "Edits", "q1": "The article file is in the folder called '", "q2": "The reporter thinks that the article file is in the folder called '", "q3": "When the reporter comes back to work, she will first look for the article file in the folder called '", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 3},
{"txt": "Lila likes it when her dog stays in the house while she's away. Thus, she locks her dog in the house before leaving for school. When Lila is gone, her mom comes home. Mom doesn't like it when the dog is locked in the house, so she takes it outside and locks it in the shed instead. The shed is made of transparent plastic and is located right next to the entrance to the house. ", "o1": "house", "o2": "shed", "q1": "The dog is in the", "q2": "Lila thinks that the dog is in the", "q3": "When Lila comes back from school, she will look for the dog in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 4},
{"txt": "It's nighttime, and Steven is doing some household chores. After hand-washing a blanket, he goes into the backyard to hang it on the clothesline next to the shed. Steven hangs the blanket without any clothespins to secure it, and then returns indoors to go to bed. Overnight, the wind blows the blanket off from the clothesline next to the shed. The blanket flies high in the air and miraculously lands on another clothesline, located next to the fence. Both clothesline are equally visible from Steven's door to the backyard. When Steven wakes up in the morning, he remembers that he needs to get his blanket. He has no idea what happened when he was asleep. ", "o1": "shed", "o2": "fence", "q1": "The blanket is on the clothesline next to the", "q2": "Steven thinks that the blanket is on the clothesline next to the", "q3": "Steven will first look for the blanket on the clothesline next to the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 5},
{"txt": "Sally and Anna are in a room. Sally puts a toy in a transparent plastic box. Sally leaves the room and goes outside to play with other children. When Sally is gone, Anna removes the toy from the box and puts it in a transparent plastic basket. ", "o1": "box", "o2": "basket", "q1": "The toy is in the", "q2": "Sally thinks that the toy is in the", "q3": "When she comes back, Sally will first look for the toy in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 6},
{"txt": "Max watched his little brother put laundry in the washing machine. Next, Max left the house to play in the courtyard. While he was gone, his brother moved the laundry from the washing machine to the dryer. Both the washing machine and the dryer have a transparent front door. ", "o1": "washing machine", "o2": "dryer", "q1": "The laundry is in the", "q2": "Max thinks that the laundry is in the", "q3": "When Max comes back to the house, he will first look for the laundry in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 8},
{"txt": "Ed saw that his daughter repaired a broken toy truck. He then left the room and kept watching her through the glass door. When he was gone, his daughter accidentally broke the toy truck again. ", "o1": "repaired", "o2": "broken", "q1": "The toy truck is", "q2": "Ed thinks that the toy truck is", "q3": "When Ed comes back to the room, he will expect that the toy truck is", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 9},
{"txt": "Mark sees a packet of cheese in the fridge, which is close to its expiry date. He plans to use it later that night when making dinner. He leaves for work. Soon, Mark's wife Jenna enters the kitchen to check which groceries need to be disposed of or restocked. She notices the cheese and places it in the freezer, thinking it will last longer that way. Both the freezer and the fridge have transparent glass doors. ", "o1": "fridge", "o2": "freezer", "q1": "The cheese is in the", "q2": "Mark thinks that the cheese is in the", "q3": "When Mark returns home, ready to prepare dinner, he will look for the cheese in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 10},
{"txt": "Fred, an IT technician, was setting up a computer for one of the newly hired consultants. He saved the letterhead file in the 'docs' folder. The computer has two folders, 'docs' and 'templates', which are both empty and the contents of the folders are visible in the preview. While Fred was out, having lunch with the other employees, the consultant dropped in to pick up her computer. As Fred was gone, his boss, Mary, inspected the computer to see whether it was ready. She noticed that the letterhead file was placed in the 'docs' folder. She remembered that in accordance with the new guidance, the letterhead file should be stored in the 'templates' folder instead. She removed it from the 'docs' folder and moved it to the 'templates' folder. She then handed the computer to the consultant. Mary decided that at the next staff meeting, she would remind her team members of the new guidance. She left the office to meet with her own boss. A few minutes later, the newly hired consultant called the IT department. Fred was still away, eating lunch, but the call was automatically redirected to his mobile phone. The consultant asked Fred to help her find the letterhead file. Fred didn't realize that Mary changed the location of the file when he was gone. ", "o1": "docs", "o2": "templates", "q1": "The letterhead is located in the '", "q2": "Fred thinks that the letterhead is in the '", "q3": "Fred will first tell the consultant to look for the letterhead in the '", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 17},
{"txt": "Protagonists A and B are in a room. A puts an object Q in a transparent container X and leaves the room. When A is away, B moves Q from container X to another transparent container Y. ", "o1": "X", "o2": "Y", "q1": "The Q is in container", "q2": "Protagonist A thinks that Q is in container", "q3": "Protagonist A, when asked, will claim that Q is in container", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 19},
{"txt": "In the room, there is John, Mark, a cat, a transparent plastic box, and a glass chest. John takes the cat and puts it in the chest. Mark takes the cat out of the chest and puts it in the box. John takes the cat out of the box and puts it in the chest. He leaves the room and goes to school. Now Mark is alone in the room. He takes the cat out of the chest and puts it in the box. John has no way of knowing what happened in the room when he was away. ", "o1": "chest", "o2": "box", "q1": "The cat jumps out of the", "q2": "John thinks that the cat is in the", "q3": "When John comes home, he will first look for the cat in the", "truth": "o2", "belief": "o2", "type": "transparent access", "idx": 20},
{"txt": "Father comes home from the grocery store. He bought bananas for banana bread. His daughter, Maria, helps him put away the shopping. She asks him: \"Where should I put the bananas?\" \"On the red box,\" says Father. Maria puts the bananas on the red box. Maria remembers exactly where she put the bananas so that she can come back and get one later. She loves bananas. Then, she leaves for school. While Maria is away, father starts to prepare the banana bread and takes those bananas from the red box. He peels and slices one of them, but then he puts the rest of them back on the yellow box instead of the red one. He realizes that he is missing eggs. He leaves the kitchen and goes to see if their neighbor has some. ", "o1": "red", "o2": "yellow", "q1": "The bananas are on the", "q2": "Maria thinks that the bananas are on the", "q3": "When Maria comes back, she will first look for the bananas on the", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 1},
{"txt": "Cecilia is about to bake a saffron cake for her son's birthday. In preparation, she places a small packet of very expensive saffron on the shelf. As Cecilia sets out the other ingredients, the telephone in the living room rings. She leaves the kitchen to attend the call. She closes the door behind her and cannot see what is happening in the kitchen. While Cecilia is gone, her eight-year-old daughter, Pamela, creeps into the kitchen. Pamela is jealous about all the attention that her brother will be receiving on his birthday, so she quietly takes the packet of saffron from the shelf and puts it on the counter. ", "o1": "shelf", "o2": "cupboard", "q1": "The saffron is on the", "q2": "Cecilia thinks that the saffron is on the", "q3": "When Cecilia comes back to the kitchen, she will first look for the saffron on the", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 2},
{"txt": "Sally and Anna are in a room. Sally puts a toy on a box. Sally leaves the room and goes outside to play with other children. When Sally is gone, Anna removes the toy from the box and puts it on an upside down basket. ", "o1": "box", "o2": "basket", "q1": "The toy is on the", "q2": "Sally thinks that the toy is on the", "q3": "When she comes back, Sally will first look for the toy on the", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 6},
{"txt": "Max watched his little brother take laundry out of the washing machine and put it on the couch. Next, Max left the house to play in the courtyard. While he was gone, his brother moved the laundry from the couch to the sofa right next to the couch. ", "o1": "couch", "o2": "sofa", "q1": "The laundry is on the", "q2": "Max thinks that the laundry is on the", "q3": "When Max comes back to the house, he will first look for the laundry on the", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 8},
{"txt": "A mermaid finds a hermit crab living on a blue shell. She is excited to tell other mermaids about her discovery and swims away to look for them. In the meantime, the hermit crab goes on top of a green shell that he has found nearby. An octopus observes all this and ponders whether it is a good time to try to catch and eat the crab, but then he decides that it is still too early for dinner. A few nautical miles away, the mermaid finds her friends smoking seaweed. Naturally, she doesn't know what happened around here in her absence. ", "o1": "blue", "o2": "green", "q1": "The crab lives on the", "q2": "The mermaid thinks that the crab lives on the", "q3": "When she comes back, the little mermaid will first look for the crab on the", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 13},
{"txt": "Protagonists A and B are in a room. A puts an object Q on top of container X and leaves the room. When A is away, B moves Q off of container X on top of container Y. ", "o1": "X", "o2": "Y", "q1": "The Q is on container", "q2": "Protagonist A thinks that Q is on container", "q3": "Protagonist A, when asked, will claim that Q is on container", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 19},
{"txt": "In the room, there is John, Mark, a cat, a box, and a basket. John takes the cat and puts it on the basket. Mark takes the cat off of the basket and puts it on the box. John takes the cat off of the box and puts it on the basket. He leaves the room and goes to school. Now Mark is alone in the room. He takes the cat off of the basket and puts it on the box. John has no way of knowing what happened in the room when he was away. ", "o1": "basket", "o2": "box", "q1": "The cat jumps out of the", "q2": "John thinks that the cat is on the", "q3": "When John comes home, he will first look for the cat on the", "truth": "o2", "belief": "o2", "type": "in->on", "idx": 20},
{"txt": "Father comes home from the grocery store. He bought bananas for banana bread. His daughter, Maria, helps him put away the shopping. She asks him: \"Where should I put the bananas?\" \"In the red drawer,\" says Father. \"Wait, I'll lift you up there, because you are too short,\" says Father, and lifts her up. Maria puts the bananas in the red drawer. Maria remembers exactly where she put the bananas so that she can come back and get one later. She loves bananas. Then, she leaves for school. While Maria is away, father starts to prepare the banana bread and takes the bananas from the red drawer. He peels and slices one of them, but then he puts the rest of them back in the yellow drawer instead of the red one. He texts Maria to tell her he left the bananas in the yellow drawer. He realizes that he is missing eggs. He leaves the kitchen and goes to see if their neighbor has some. ", "o1": "red", "o2": "yellow", "q1": "The bananas are in the", "q2": "Maria thinks that the bananas are in the", "q3": "When Maria comes back, she will first look for the bananas in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 1},
{"txt": "Cecilia is about to bake a saffron cake for her son's birthday. In preparation, she places a small packet of very expensive saffron in the drawer, which is under the cupboard. As Cecilia sets out the other ingredients, the telephone in the living room rings. She leaves the kitchen to attend the call. She closes the door behind her and cannot see what is happening in the kitchen. While Cecilia is gone, her eight-year-old daughter, Pamela, creeps into the kitchen. Pamela is jealous about all the attention that her brother will be receiving on his birthday, so she quietly takes the packet of saffron from the drawer and hides it in the cupboard. In the last minute, Pamela regrets what she did and tells her mom. ", "o1": "drawer", "o2": "cupboard", "q1": "The saffron is in the", "q2": "Cecilia thinks that the saffron is in the", "q3": "When Cecilia comes back to the kitchen, she will first look for the saffron in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 2},
{"txt": "It's the end of the day shift at a newsroom, and a reporter has almost finished writing an article on the office computer. There are two folders on the desktop screen: 'Drafts' and 'Edits.' Intending to complete the article the next day, she saves the article in 'Drafts' and leaves the newsroom. Soon she is at home and fast asleep. When the reporter is gone, the staff proofreader enters the office to begin his night shift. He browses through the two folders to see if there's anything he should work on. He notices that the article that the reporter wrote is an urgent piece that needs to be published as soon as possible. He decides to write the concluding paragraph and have it ready for the design team. After the article is finished and proofread, he moves it into the 'Edits' folder. He sends the reporter an email to tell her he moved the article to the 'Edits' folder. The next day in the morning, the reporter wakes up. ", "o1": "Drafts", "o2": "Edits", "q1": "The article file is in the folder called '", "q2": "The reporter thinks that the article file is in the folder called '", "q3": "When the reporter comes back to work, she will first look for the article file in the folder called '", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 3},
{"txt": "Lila likes it when her dog stays in the house while she's away. Thus, she locks her dog in the house before leaving for school. When Lila is gone, her mom comes home. Mom doesn't like it when the dog is locked in the house, so she takes it outside and locks it in the shed instead. She then texts Lila to tell her she moved the dog to the shed. ", "o1": "house", "o2": "shed", "q1": "The dog is in the", "q2": "Lila thinks that the dog is in the", "q3": "When Lila comes back from school, she will look for the dog in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 4},
{"txt": "It's nighttime, and Steven is doing some household chores. After hand-washing a blanket, he goes into the backyard to hang it on his clothesline. Steven hangs the blanket without any clothespins to secure it, and then returns indoors to go to bed. Overnight, the wind blows the blanket off from his clothesline. The blanket flies high in the air and miraculously lands on his neighbor's clothesline, When Steven wakes up in the morning, he remembers that he needs to get his blanket. He has no idea what happened when he was asleep. On his way outside, his neighbor tells him that she found his blanket on her clothesline. ", "o1": "shed", "o2": "fence", "q1": "The blanket is on the clothesline next to the", "q2": "Steven thinks that the blanket is on the clothesline next to the", "q3": "Steven will first look for the blanket on the clothesline next to the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 5},
{"txt": "Sally and Anna are in a room. Sally puts a toy in a box. Sally leaves the room and goes outside to play with other children. When Sally is gone, Anna removes the toy from the box and puts it in a basket. She then opens the window and shouts to Anna that she moved the toy to the basket. ", "o1": "box", "o2": "basket", "q1": "The toy is in the", "q2": "Sally thinks that the toy is in the", "q3": "When she comes back, Sally will first look for the toy in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 6},
{"txt": "Mark puts his blue basketball in a box and closes it. This is a magical box, which changes colors of things that are left inside. After a few minutes, the basketball turns green. Mark cannot see what happened inside the magical box, but his sister who got him the box tells him that it turns blue objects green. ", "o1": "blue", "o2": "green", "q1": "Mark opens the box and can see that the basketball is now", "q2": "Mark thinks that the color of basketball is", "q3": "When Mark opens the box, he is going to expect that the color of the basketball is", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 7},
{"txt": "Max watched his little brother put laundry in the washing machine. Next, Max left the house to play in the courtyard. While he was gone, his brother moved the laundry from the washing machine to the dryer. He texted Max to let him know, and then left the house too. ", "o1": "washing machine", "o2": "laundry basket", "q1": "The laundry is in the", "q2": "Max thinks that the laundry is in the", "q3": "When Max comes back to the house, he will first look for the laundry in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 8},
{"txt": "Ed saw that his sister repaired a broken toy truck. He then left the room and had no way of knowing what was happening there. When he was gone, his sister accidentally broke the toy truck again. He heard her shouting angrily that the toy broke again so he went back to the room. ", "o1": "repaired", "o2": "broken", "q1": "The toy truck is", "q2": "Ed thinks that the toy truck is", "q3": "When Ed comes back to the room, he will expect that the toy truck is", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 9},
{"txt": "Mark sees a packet of cheese in the fridge, which is close to its expiry date. He plans to use it later that night when making dinner. He leaves for work. Soon, Mark's wife Jenna enters the kitchen to check which groceries need to be disposed of or restocked. She notices the cheese and places it in the freezer, thinking it will last longer that way. She texts Mark to tell him that she moved the cheese. ", "o1": "fridge", "o2": "freezer", "q1": "The cheese is in the", "q2": "Mark thinks that the cheese is in the", "q3": "When Mark returns home, ready to prepare dinner, he will look for the cheese in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 10},
{"txt": "At the end of the day, Anita is packing up her belongings as she gets ready to leave her workplace. She forgets her watch in the conference room. After she leaves, Anita's secretary comes in to tidy up. He sees the watch and picks it up. He leaves the watch at the reception. and calls Anita to let her know where to pick it up the next morning. ", "o1": "conference room", "o2": "reception", "q1": "The watch is in the", "q2": "Anita thinks that the watch is in the", "q3": "When she comes back to work, Anita will first look for her watch in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 11},
{"txt": "Frank and his wife Maria have two bank accounts: savings and checking. Their savings account was empty, but early in January, Frank sold their old car for $5,000 and deposited the money in their savings account. In February, Maria realized that they owe a lot of taxes. She logged in to their online bank platform and transferred all this money from their savings account to their checking account. The bank automatically notifies both Frank and Maria about any changes in the account. A few days later, Frank decided to retrieve the proceeds from selling their old car to buy a new one. ", "o1": "savings", "o2": "checking", "q1": "The proceeds from selling their old car are in their", "q2": "Frank thinks that the proceeds from selling their old car are in their", "q3": "When he goes to the bank, Frank will ask the bank teller to look for the money in their", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 12},
{"txt": "The insurgents hide in the forest in Nottinghamshire. They are working on planning their next attack on the army checkpoint. One of the local farmers spots the insurgents and reports their whereabouts to the army. The army puts the troops on high alert and prepares to surround the insurgents. The insurgents realize what is going on and decide to abandon their base. They pack their tents and their weapons, and move to the forest in Oxfordshire. The neighbors see this and report it to the army. They set up their base and start planning their next cunning attack. ", "o1": "Nottinghamshire", "o2": "Oxfordshire", "q1": "The insurgents are now hiding in the forest in", "q2": "The army thinks that the insurgents are hiding in the forest in", "q3": "When the army attacks, they will first search for the insurgents in the forest in", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 14},
{"txt": "The prime minister has long believed that her government's flagship project, the introduction of universal basic income (UBI), should be supervised by the Minister of Finance. She was, however, becoming increasingly disappointed with the slow progress on this project. On Thursday morning, after a meeting with her advisor, she changed her mind. She decided that the project should be now supervised by the Minister of Internal Affairs. She updated the members of the cabinet on her decision. ", "o1": "Finance", "o2": "Internal Affairs", "q1": "The prime minister thinks that the introduction of the UBI should be supervised by the Minister of", "q2": "The members of the cabinet think that the person supervising the introduction of the UBI is the Minister of", "q3": "When they arrive at the cabinet meeting next week, the members of the cabinet will expect that the person responsible for the introduction of the UBI is the Minister of", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 15},
{"txt": "After months of fighting, the leaders of Azerbaijan and Armenia meet to discuss a peace treaty. They agree to transfer the authority over Nagorno-Karabakh from the former to the latter country. The agreement goes into effect immediately, but was planned to be announced to the residents of Nagorno-Karabakh at a press conference, on the next day, however, one of the leaders leaked the story to the media. ", "o1": "Azerbaijan", "o2": "Armenia", "q1": "As of now, the authority over Nagorno-Karabakh is held by the government of", "q2": "As of now, the residents of Nagorno-Karabakh think that the authority over their land is held by the government of", "q3": "After the meeting was over, but before the press conference, a Reuters journalist was interviewing Maria, an elderly resident of Nagorno-Karabakh. When asked who had the authority over her land, Maria said that it was the government of", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 16},
{"txt": "Fred, an IT technician, was setting up a computer for one of the newly hired consultants. He saved the letterhead file in the 'docs' folder. While Fred was out, having lunch with the other employees, the consultant dropped in to pick up her computer. As Fred was gone, his boss, Mary, inspected the computer to see whether it was ready. She noticed that the letterhead file was placed in the 'docs' folder. She remembered that in accordance with the new guidance, the letterhead file should be stored in the 'templates' folder instead. She removed it from the 'docs' folder and moved it to the 'templates' folder. She then handed the computer to the consultant, and texted Fred about this. She left the office to meet with her own boss. A few minutes later, the newly hired consultant called the IT department. Fred was still away, eating lunch, but the call was automatically redirected to his mobile phone. The consultant asked Fred to help her find the letterhead file. ", "o1": "docs", "o2": "templates", "q1": "The letterhead is located in the '", "q2": "Fred thinks that the letterhead is in the '", "q3": "Fred will first tell the consultant to look for the letterhead in the '", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 17},
{"txt": "Protagonists A and B are in a room. A puts an object Q in container X and leaves the room. When A is away, B moves Q from container X to container Y. B leaves a note to A on the door describing what they did. ", "o1": "X", "o2": "Y", "q1": "The Q is in container", "q2": "Protagonist A thinks that Q is in container", "q3": "Protagonist A, when asked, will claim that Q is in container", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 19},
{"txt": "In the room, there is John, Mark, a cat, a box, and a basket. John takes the cat and puts it in the basket. Mark takes the cat out of the basket and puts it in the box. John takes the cat out of the box and puts it in the basket. He leaves the room and goes to school. Mark calls John to tell him he is going to move the cat to the box. John believes him. Now Mark is alone in the room. He takes the cat out of the basket and puts it in the box. John has no way of knowing what happened in the room when he was away. ", "o1": "basket", "o2": "box", "q1": "The cat jumps out of the", "q2": "John thinks that the cat is in the", "q3": "When John comes home, he will first look for the cat in the", "truth": "o2", "belief": "o2", "type": "trusted testimony", "idx": 20},
{"txt": "Father comes home from the grocery store. He bought bananas for banana bread. His daughter, Maria, helps him put away the shopping. She asks him: \"Where should I put the bananas?\" \"In the red drawer,\" says Father. Maria puts the bananas in the red drawer. Then, her dad leaves for work. While father is away, Maria starts to prepare the banana bread and takes the bananas from the red drawer. She peels and slices one of them, but then she puts the rest of them back in the yellow drawer instead of the red one. She realizes that she is missing eggs. She leaves the kitchen and goes to see if their neighbor has some. ", "o1": "red", "o2": "yellow", "q1": "The bananas are in the", "q2": "Maria thinks that the bananas are in the", "q3": "When Maria comes back, she will first look for the bananas in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 1},
{"txt": "Cecilia is about to bake a saffron cake for her son's birthday. In preparation, she places a small packet of very expensive saffron in the drawer, which is under the cupboard. As Cecilia takes it out and puts the ingredients on the table, the telephone in the living room rings. She puts the packet in the cupboard and leaves the kitchen to attend the call. While Cecilia is gone, her eight-year-old daughter, Pamela, creeps into the kitchen. Pamela is jealous about all the attention that her brother will be receiving on his birthday, so she quietly takes the eggs from the fridge and hides them in the drawer. She hopes that her mother will not be able to find it. ", "o1": "drawer", "o2": "cupboard", "q1": "The saffron is in the", "q2": "Cecilia thinks that the saffron is in the", "q3": "When Cecilia comes back to the kitchen, she will first look for the saffron in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 2},
{"txt": "At a newsroom, a reporter has almost finished writing an article on the office computer. There are two folders on the desktop screen: 'Drafts' and 'Edits.' Reporters save drafts of their articles to the 'Drafts' folder, and the staff proofreader edits them and moves them to the 'Edits' folder, for the design team. She saves the article in 'Drafts' and goes out for lunch. When the reporter is away, the staff proofreader starts editing the article, but he has some clarification questions, so he waits for her to come back to work on the editing together. The next day in the morning, the reporter wants to check something in the article. ", "o1": "Drafts", "o2": "Edits", "q1": "The article file is in the folder called '", "q2": "The reporter thinks that the article file is in the folder called '", "q3": "When the reporter comes back to work, she will first look for the article file in the folder called '", "truth": "o2", "belief": "o2", "type": "other person", "idx": 3},
{"txt": "Lila likes it when her dog stays in the house while she's away. Thus, she locks her dog in the house before leaving for school. Today, her mom came home right before she left for school. Mom doesn't like it when the dog is locked in the house, so Lila took it outside and locked it in the shed instead. ", "o1": "house", "o2": "shed", "q1": "The dog is in the", "q2": "Lila thinks that the dog is in the", "q3": "When Lila comes back from school, she will look for the dog in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 4},
{"txt": "Sally and Anna are in a room. Sally puts a toy in a box. Anna leaves the room and goes outside to play with other children. When Anna is gone, Sally removes the toy from the box and puts it in a basket. She then leaves the room to join Sally and the other children. ", "o1": "box", "o2": "basket", "q1": "The toy is in the", "q2": "Sally thinks that the toy is in the", "q3": "When she comes back, Sally will first look for the toy in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 6},
{"txt": "Mark puts his blue basketball in a box and closes it. Mark bought this magical box, that changes the colors of things that are left inside to the favorite color of the person holding the box. After a few minutes, the basketball turns green. Mark cannot see what happened inside the magical box. ", "o1": "blue", "o2": "green", "q1": "Mark opens the box and can see that the basketball is now", "q2": "Mark thinks that the color of basketball is", "q3": "When Mark opens the box, he is going to expect that the color of the basketball is", "truth": "o2", "belief": "o2", "type": "other person", "idx": 7},
{"txt": "Max watched his little brother put laundry in the washing machine. Next, his little brother left the house to play in the courtyard. While he was gone, Max moved the laundry from the washing machine to the laundry basket. He then to join his brother in the courtyard. ", "o1": "washing machine", "o2": "laundry basket", "q1": "The laundry is in the", "q2": "Max thinks that the laundry is in the", "q3": "When Max comes back to the house, he will first look for the laundry in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 8},
{"txt": "Ed saw that his sister repaired a broken toy truck. She then left the room and had no way of knowing what was happening there. When she was gone, he accidentally broke the toy truck again. He then left the room too. ", "o1": "repaired", "o2": "broken", "q1": "The toy truck is", "q2": "Ed thinks that the toy truck is", "q3": "When Ed comes back to the room, he will expect that the toy truck is", "truth": "o2", "belief": "o2", "type": "other person", "idx": 9},
{"txt": "Mark sees a packet of cheese in the fridge, which is close to its expiry date. He plans to use it later that night when making dinner. He tells his wife Jenna that the cheese is in the fridge before she leaves for work. He then remembers that he has a work dinner in a restaurant, so he places it in the freezer, thinking it will last longer that way. Mark leaves for work. ", "o1": "fridge", "o2": "freezer", "q1": "The cheese is in the", "q2": "Mark thinks that the cheese is in the", "q3": "When Mark returns home, ready to prepare dinner, he will look for the cheese in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 10},
{"txt": "At the end of the day, Anita is packing up her belongings as she gets ready to leave her workplace. She forgets her watch in the conference room. On her way home, she calls her secretary and asks him to leave the watch at the reception. ", "o1": "conference room", "o2": "reception", "q1": "The watch is in the", "q2": "Anita thinks that the watch is in the", "q3": "When she comes back to work, Anita will first look for her watch in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 11},
{"txt": "Frank and his wife Maria have two bank accounts: savings and checking. Their savings account was empty, but early in January, Frank sold their old car for $5,000 and deposited the money in their savings account. In February, Maria realized that they owe a lot of taxes. She asked him to transfer the money from their savings account to their checking account, because she has no access to online banking. A few days later, Frank decided to retrieve the proceeds from selling their old car to buy a new one. ", "o1": "savings", "o2": "checking", "q1": "The proceeds from selling their old car are in their", "q2": "Frank thinks that the proceeds from selling their old car are in their", "q3": "When he goes to the bank, Frank will ask the bank teller to look for the money in their", "truth": "o2", "belief": "o2", "type": "other person", "idx": 12},
{"txt": "The insurgents hide in the forest in Nottinghamshire. They are working on planning their next attack on the army checkpoint. One of the local farmers spots the insurgents and reports their whereabouts to the army. To confuse them, he tells them that he is on their side and that they shouldn't worry because he would tell the army that they are in Oxfordshire. The army puts the troops on high alert and prepares to surround the insurgents. ", "o1": "Oxfordshire", "o2": "Nottinghamshire", "q1": "The insurgents are now hiding in the forest in", "q2": "The army thinks that the insurgents are hiding in the forest in", "q3": "When the army attacks, they will first search for the insurgents in the forest in", "truth": "o2", "belief": "o2", "type": "other person", "idx": 14},
{"txt": "The prime minister has long believed that her government's flagship project, the introduction of universal basic income (UBI), should be supervised by the Minister of Finance. She was, however, becoming increasingly disappointed with the slow progress on this project. On Thursday morning, during a meeting with the Minister of Finance, they decided that the project should be now supervised by the Minister of Internal Affairs. They decided not to tell the Minister of Internal Affairs about her change of mind, for now. She will announce it during their meeting next week. ", "o1": "Finance", "o2": "Internal Affairs", "q1": "The prime minister thinks that the introduction of the UBI should be supervised by the Minister of", "q2": "The Minister of Finance think that the person supervising the introduction of the UBI is the Minister of", "q3": "When the Minister of Finance arrives to his weekly meeting with the PM next week, he will expect that the person responsible for the introduction of the UBI is the Minister of", "truth": "o2", "belief": "o2", "type": "other person", "idx": 15},
{"txt": "Fred, an IT technician, was setting up a computer for one of the newly hired consultants. He saved the letterhead file in the 'docs' folder. While Fred was out, having lunch with the other employees, the consultant dropped in to pick up her computer. As Fred was gone, his boss, Mary, inspected the computer to see whether it was ready. She noticed that the letterhead file was placed in the 'docs' folder. She remembered that in accordance with the new guidance, the letterhead file should be stored in the 'templates' folder instead. She send Fred an email about it and he fixed it remotely from his phone. She then handed the computer to the consultant. She left the office to meet with her own boss. A few minutes later, the newly hired consultant called the IT department. Fred was still away, eating lunch, but the call was automatically redirected to his mobile phone. The consultant asked Fred to help her find the letterhead file. ", "o1": "docs", "o2": "templates", "q1": "The letterhead is located in the '", "q2": "Fred thinks that the letterhead is in the '", "q3": "Fred will first tell the consultant to look for the letterhead in the '", "truth": "o2", "belief": "o2", "type": "other person", "idx": 17},
{"txt": "Protagonists A and B are in a room. A puts an object Q in container X and leaves the room. When A is away, B moves Q from container X to container Y. A then comes back and moves the object back to Y. This time, A locks the door. Only A has the key. A comes back to the room the next day. ", "o1": "X", "o2": "Y", "q1": "The Q is in container", "q2": "Protagonist A thinks that Q is in container", "q3": "Protagonist A, when asked, will claim that Q is in container", "truth": "o2", "belief": "o2", "type": "other person", "idx": 19},
{"txt": "In the room there are John, Mark, a cat, a box, and a basket. John takes the cat and puts it in the basket. He leaves the room and goes to school. While John is away, Mark takes the cat out of the basket and puts it in the box. Mark leaves the room and goes to work. John and Mark come back and enter the room. They don't know what happened in the room when they were away. ", "o1": "basket", "o2": "box", "q1": "The cat jumps out of the", "q2": "John thinks that the cat is in the", "q3": "When John comes home, he will first look for the cat in the", "truth": "o2", "belief": "o2", "type": "other person", "idx": 20}
"""]

# %% [markdown]
# # Zero-Shot

# %%
j=1
for content in tasks:
  print("================================= TASK #"+str(j)+ " ================================= ")
  gpt(template=content["txt"]+content["q1"])
  print("=================================")
  gpt(template=content["txt"]+content["q2"])
  print("=================================")
  gpt(template=content["txt"]+content["q3"])
  j=j+1
# Out:
# ================================= TASK #1 =================================
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:202: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:790: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# yellow drawer.
# ...
# yellow drawer, but when she goes to get one later, she finds that they are not there. Confused, she searches the kitchen and finally finds the bananas in the yellow drawer. She realizes that her father must have moved them while she was at school. Maria takes a banana and enjoys it before continuing with her day.
# ...

# %% [markdown]
# # Step-by-Step Thinking

# %%
j=0
for content in tasks:
  content["NUMBER"]=j
  print("================================= TASK #"+str(content["NUMBER"])+ " ================================= ")
  gpt(template=content["txt"]+"Let's think step by step"+content["q1"])
  print("=================================")
  gpt(template=content["txt"]+"Let's think step by step"+content["q2"])
  print("=================================")
  gpt(template=content["txt"]+"Let's think step by step"+content["q3"])
  j=j+1
# Out:
# ================================= TASK #0 =================================
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:202: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:790: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# yellow drawer.
# ...
# red drawer.
# ...
# red drawer where she originally put them. However, she will not find them there because her father moved them to the yellow drawer. Confused, Maria may wonder where the bananas went and why they are not in the red drawer.
#
# ...

# %% [markdown]
# # Two-Shot CoT

# %%
shot=[{"txt": "Read the scenario and complete the last sentence. Scenario: In the room, there is John, Mark, a cat, a box, and a basket. John takes the cat and puts it in the basket. Mark takes the cat out of the basket and puts it in the box. John takes the cat out of the box and puts it in the basket. He leaves the room and goes to school. Now Mark is alone in the room. He takes the cat out of the basket and puts it in the box. John has no way of knowing what happened in the room when he was away. ",
       "o1": "basket",
       "o2": "box",
       "q1": "The cat jumps out of the",
       "q2": "John thinks that the cat is in the",
       "q3": "When John comes home, he will first look for the cat in the",
         "a1": "box, because finally Mark put the cat in the box.",
       "a2": "basket, because John didn't know Mark has put the cat in the box when he was not in the room",
       "a3": "basket. John didn't know Mark has put the cat in the box when he was not in the room and he still thinks that the cat is in the basket."}]

j=0
for content in tasks:
  content["NUMBER"]=str(j)
  print("================================= TASK #"+content["NUMBER"]+ " ================================= ")
  gpt(template=shot[0]["txt"]+shot[0]["q1"]+shot[0]["a1"]+content["txt"]+content["q1"])
  print("=================================")
  gpt(template=shot[0]["txt"]+shot[0]["q2"]+shot[0]["a2"]+content["txt"]+content["q2"])
  print("=================================")
  gpt(template=shot[0]["txt"]+shot[0]["q3"]+shot[0]["a3"]+content["txt"]+content["q3"])
  j=j+1
# Out:
# ================================= TASK #0 =================================
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:202: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:790: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# yellow drawer.
# ...
# yellow drawer, because she didn't know that her father moved them while she was at school.
# ...
# red drawer.
# ================================= TASK #1 =================================
# cupboard.
# ...
# drawer, because she did not see Pamela take it and hide it in the cupboard.
# ...
# drawer.
# ================================= TASK #2 =================================
# Edits'.
# ...
